# %%
#importing the necessary libraries
import numpy as np
import pandas as pd

# %%
#reading the data
df = pd.read_csv('/content/tweets.csv')

# %%
#checking the first few rows of the data
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...

# %%
#dropping off id column because its irrelevant
df.drop('id',axis=1,inplace=True)

# %%
df.head()
# Out:
#    label                                              tweet
# 0      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1      0  Finally a transparant silicon case ^^ Thanks t...
# 2      0  We love this! Would you go? #talk #makememorie...
# 3      0  I'm wired I know I'm George I was made that wa...
# 4      1  What amazing service! Apple won't even talk to...

# %%
df.shape
# Out:
# (7920, 2)

# %%
#cheking the unique values of column label
df['label'].value_counts()
# Out:
# label
# 0    5894
# 1    2026
# Name: count, dtype: int64

# %% [markdown]
# #data preprocessing

# %%
#writing a function to remove the punctuations from text
import string
def remove_punctuation(text):
  punctuationfree = "".join([i for i in text if i not in string.punctuation])
  return punctuationfree

# %%
#writing a function to tokenize each word of text
import nltk
nltk.download('punkt')
def tokenization(text):
  words = nltk.word_tokenize(text)
  return words
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#writing a function to remove the stopwords
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
def remove_stopwords(text):
  output = [i for i in text if i not in stopwords]
  return output
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#writing a function to convert words into lemmas
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatizer(text):
  lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
  return lemm_text
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
#wrting the function to process all the above functions
def preprocess(df_col):
  corpus =[]
  for item in df_col:
    new_item = remove_punctuation(item)
    new_item = new_item.lower()
    new_item = tokenization(new_item)
    new_item = remove_stopwords(new_item)
    new_item = lemmatizer(new_item)
    corpus.append(' '.join(str(x) for x in new_item))
  return corpus

# %%
# creating our corpus
corpus = preprocess(df.tweet)

# %%
corpus
# Out:
# ['fingerprint pregnancy test httpsgooglh1mfqv android apps beautiful cute health igers iphoneonly iphonesia iphone',
#  'finally transparant silicon case thanks uncle yay sony xperia sonyexperias… httpinstagramcompyget5jc6jm',
#  'love would go talk makememories unplug relax iphone smartphone wifi connect httpfbme6n3lsupcu',
#  'im wired know im george made way iphone cute daventry home httpinstagrampli5ujs4k',
#  'amazing service apple wont even talk question unless pay 1995 stupid support',
#  'iphone software update fucked phone big time stupid iphones',
#  'happy u instapic instadaily u sony xperia xperiaz httpsinstagramcompz9qgfwlvj7',
#  'new type c charger cable uk httpwwwebaycoukitm112598674021 … bay amazon etsy new year rob cross toby young evemun mcmafia taylor spectre 2018 newyear starting 2018 recipe technology samsunggalaxys9 iphonex pictwittercompjiwq59wtc',
#  'bout go shopping listening music iphone justme music likeforlike followforfollow… httpinstagrampvj6bg5tlql',
#  'photo fun selfie pool water sony camera picoftheday sun instagood boy cute outdoor httptmblrcozajc0n1msgp8',
#  'hey apple make new ipod dont make new color 2inches thinner make crash every five fuckin minite',
#  'ha heavy machinery need apple really dropped ball design drinkyourhaterade',
#  'contemplating giving iphone bandwagon simply cellcom new android depressing idontwantto',
#  'made another crazy purchase lol theory work hard play hard lol ipad apple shopping httpinstagrampnuyfhvye7i',
#  'shaqlockholmes samlouise1991 battery painful charge overnight lunchtime battery dead hateorange',
#  'deepellum towards downtown dallas bigd saturday rx100m3 sony summer urban httpinstagramcomppzjooaqqz4',
#  'like share want 3d phone case iphone iphone httpsbestcheapphonescomindexphpproduct2016newsweet3dmineralwaterbottleloveicecreamphonecasecouplessoftsiliconerubbercaseforiphone766splus55se …pictwittercomgfkn0yec6j',
#  'go crazy iphonesia iphone instagood instagram photooftheday tweegram … httpinstagramcompd0r5sqry5b',
#  'reason dont one iphone suck apple truth truthbetold agree fact realitycheck blackberrypictwittercomzpggd7cazn',
#  'apple store gunna 5c screen monday ur fucking apple store fuckingpissed',
#  'apple art easter dear friend would like published channel design face easter bunny email png thumbnail email mutitaedibleartgmailcompictwittercom7jhwphfbgt',
#  'excuse waiter seems pie soup wife bake apple pie yay httpinstagrampq8g43jpimn',
#  'ive new ipod four day button back broke accidentally hit',
#  'iphone screen go completely black keep getting text day cant fucking check apple 6thiphone',
#  'time new wallpaper phone wallpaper wall screen galaxy samsung app … httpswwwinstagramcompbcsktnnn51c',
#  '105 billion 3 patent prior art 300 million patent troll partying thanks apple apple',
#  'ipod messed havent done nothing myloss apple',
#  'ipod touch frozen apple logo start lose demis music pic kill someone soangry hateapple',
#  'love new phone case flower green diamond pearl cute new iphone iphone4s case… httpinstagrampwelxefuno',
#  'must watch youtube subscribe daily vlog twitch gaming fun ps4 xbox sony game io android httpsyoutubeoaxlm8r5sda',
#  'thank samsung live laugh life food philippine instago instahub instagram… httpinstagramcompyxhudzhhfb',
#  'ch cannon suewee friendship americanbully dog piggy family southerncharm americanidol goal bestfriends pitbull iphonex onelove country muscle nfl worldwide america bigboy thislife tmz wild hoggpictwittercom1mn5ogpi2c',
#  'instapic mimmoal feb 2016 taken sony rx100 direzioneverticale sunset sky beautiful fun …pictwittercomcxifijj54g',
#  'im happy sister bought new phone early bday gift happy samsung s4',
#  'received samsung note 2 many thanks cottds phone httpinstagrampriqsbabgo',
#  'nswrl app android market pipeline',
#  'cant delete individual song phone apple itunes',
#  'everybody freaking ios7 im like duuude even window phone advanced iphones customization',
#  'new iphone 5 5c standing sirriiously bad c standing cheap screen re camera tech apple',
#  'bull instasize legging lightskin curlyhair iphone bellypiercing smile potd… httpinstagramcompesxzmizbl8',
#  'din ’ create ’ let destroy candid photo iphonex sunday sundayvibes smile always photooftheday eye ootd fashion blackandwhite poser attitude lifeisgood mylook mylife photoeveryday lookoftheday latepost mylifepictwittercommmhcqyad9b',
#  'film set building timelapse video photooftheday beautiful producer live fashion videoproduction cute follow commercial iphone apple actor actress iphonesia hollywood losangeles picoftheday movie acting startup startupvideos shotoniphonpictwittercom94eceiaine',
#  'new phone cupcake wallpaper pink cute sweet samsung cherry httpinstagramcompxhroikktlp',
#  'eeeeee sexy lady live iphone iphonesia instagood photooftheday tweegram iphon httpinstagramprbxwmdnv5h',
#  'acquisto del week end iphone8 iphone8plus apple gril moment italy… httpswwwinstagramcompbzy3xcxh0qv',
#  'majestic see differently photography nature landscape forest hidden clearing view wood tree travel biker sony a7 ziess photo instgramhub picoftheday httpswwwinstagramcompbkvrsqjgtnutmsourceigtwittershareigshidsoka2bd9sb8h …',
#  'google apple cut itunes get program',
#  'ahhhh look got christmas 3 iphone apple christmas girl httpinstagrampbdvcq',
#  'love like love instacool photooftheday iphone instago food followforfollow 20likeshttpfbme60tnxfdk6',
#  'follow play bitcoinboy iphone ipad ipod free game fun kansa georgia … httpinstagramcompm7ssn3kapx',
#  'ogochocinco would new talking antoine iphone app check 106 u ent appstore httpbarkbarkcoweeblycomtalkingantoinehtml …',
#  'joy peace reflect remember sky cloud cloudhub skyhub tree gr iphone… httpinstagrampvj5fqyanc1',
#  'love baby boy baby boy babyboy muesli hedgehog pet iphone iphone7… httpswwwinstagramcompbz9dwxjampt',
#  'inbox letter editor news photography fashion health fail tech ipad iphone funny lolpictwittercomik1rhumovz',
#  'zsofimonster thinner faster amazing hated ipad getting one ye…',
#  'jamesdawute like tablet personally use sense im fan think quite gd product',
#  'black friday called ‘ black friday ’ httpswwwbostoncomnewsbusiness20171123whyisblackfridaycalledblackfriday … blackfridaydeals blackfriday blackfriday2017 news amazon shopping shop christmas holiday gift family friend newyork business crowd money birthday tv iphone computer lifehacks school',
#  'apple seriously afraid profit going someone else ’ pocket make charger “ ’ supported ” phone 18 po apple charger broke month getting phone good job apple',
#  'phone actually killing paying £209 replacement',
#  'cant agree thats im still programmed basic rt sloanlovescudi apple suck droid',
#  'waitwhat double check saw alyssa fun camera iphone 4h cool picture l httpinstagrampurheizynkc',
#  'cycle life complete froot apple run dog sun beach sport health httpsinstagramcompzkg66tkpug',
#  'tysonj thats bit hypocritical use hashtag apple yet quivering anticipation arrival new phone',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow ff i7si',
#  'geometry iphoneography iphoneonly iphoneography2018 streetphotography iphonephotography mobilephotography mobile iphone apple color bright … httpswwwinstagramcompbl7wqpuf4n4utmsourceigtwittershareigshidquadeby0r4ec …',
#  'iphone user httpbitlycuy0le fettish phone mobile iphone sexy technology techno indie dating okcupid',
#  'photo love le pink iphone random instamood photography loljk httptmblrcoz3txiw14vjql0',
#  'shine bright like wine amaliexmaria amazing beautiful copenhagen creative composer denmark fun f4f hot iconic keepthefaith l4l mariajensen music original pop producer red rock soul singer songwriter song universal sony warnerpictwittercomgbeusyed5m',
#  'tescophoneshop samsung galaxy2 wedding dvd thought id lost day',
#  'rt meliiecandy apple ipadmini3 soldes instamoment planeteig01 new baby instasize httpswwwinstagramcompbaniubthwgk',
#  'feeling broken phone screen replaced iphone happiness pictwittercomygsuke2ces',
#  'light way please lamp light photooftheday instagood life pekanbaru riau indonesia photography streetphotography sony a6000 sonya6000… httpswwwinstagramcompbkqbe4gg5d5utmsourceigtwittershareigshid1g2cumgyriqbc …',
#  'new acquisition iphone 5 gold apple phone brussels potd picoftheday… httpinstagramcompzs9nfenq3h',
#  'havent texted back phone reset work sorry iphone',
#  'happy sunday samsung phone smile inception white tea chilling httpinstagramcomplclty4s9pd',
#  'carcasa clear cover para samsung grandprime felizdomingo samsunggalaxy g530 felizlunes felizsemana 2oct 3oct felizmartespictwittercomxtldsjwpz9',
#  'apple mighty mouse came 2 lithium aa apple magic mouse come 2 alkaline aa magic mouse 20 apple',
#  'nyclesbians followsunday followback rt teamfollowback follow retweet iphone keep ya thing',
#  '’ happy samsunguk samsung ’ tumble dryer 4 month ’ replaced already problem occurred iwant issue resolved want able return product back samsung im alexandraeton bbcwatchdog',
#  'lilya0716 retweet a7sll sony sonya7s2 throwback shoot blury nature pic photo girl smile art …pictwittercom3btew6b4kx',
#  'cnet call apple phone put absurd price new apple device tech',
#  'commonwealth game skye nicolson win boxing gold memory dead brother – commonwealth game 2018 adaptive galatasaray iherborder samsung presidenttrump httpsbibleofsportcoukcommonwealthgamesskyenicolsonwinsboxinggoldinmemoryofherdeadbrotherscommonwealthgames2018 …',
#  'oh dear joy new iphone 5 good comment lip service win getalife apple tecshit',
#  'love finally enjoying game ps3 tombraider laracroft playstation samsung gamer … httpinstagramcompkwljdvl8ua',
#  'hunger game simpson simpson thehungergames iphone instagram apple always 2012 httpinstagrampraufmlac6m',
#  'apple called made something wrong right today make thank',
#  'new item jammieexoxo recommends iphone apple earphone earpods white lifestyle amazing… httpinstagramcompeskd0dlzmu',
#  'fuckyou apple never ending bug like payed 2 buck phonehow little quality hereanotherangrycustomer',
#  'cute girlfriend happy one year love you3 gf bf card cute sony xperia z soppy httpinstagramcompylrdyhmxi6',
#  'birthday present mom apple macbookpro macbook birthday stockholm sweden compute httpinstagrampm1b7jej3zk',
#  'photo quote day quote wisdom word smile follow tweetgram cute iphone fashion httptmblrcozsf7etoeel4f',
#  'samsunguk applaud samsung sheffield store customer service great service quality repair done hour',
#  'lost everything due freaking iphone update put recovery mode',
#  'mashable apple hater yousuck briantong easytotalk producesomething usa company korean samsung fan loser',
#  'thanks working server day sony dumb scheduled maintenance today sony httpinstagramcompxdkdtmllhl',
#  'new model byhilalak earphone urbanears handmade hayatinarenkkat iphone sony … httpswwwinstagramcompbaah6ogrpkh',
#  'photo itunes vicio nellyfurtado nelstar playingnow iphoneonly iphone diva cd httptmblrcoztrtdv101ydf6',
#  'see many feature didnt know iphone httpbitly1nutukg iphone yourtechcompany pictwittercomhs206iza4y',
#  'happiness box yey phone sony xperia sonyxperiaz new blessed… httpinstagramcompexaj7tlosm',
#  'feliz sábado con café saturday coffee pantry iphonex httpswwwinstagramcompblnydyyn6rhutmsourceigtwittershareigshidaby8xrg10o0a …',
#  'dreamy effect created straight iphone impressive spring flower blossom… httpinstagramcomptpogyugzze',
#  'finalllllly note 4 note4 samsung galaxy galaxynote4 awsome beamman best… httpinstagramcompx2mtijq5lu',
#  'special app valentine httpsitunesapplecomusapplove360id809353957mt8 … fashion nowplaying daughter poem valentine iphone αγάπη 27',
#  'photo day 36 erie pa car sign iloveyou blackandwhite streetphotography iphone erie pa httpinstagrampjrdvj',
#  'lunch park apple carrot banana lovely dog tree autumn leaves… httpswwwinstagramcompbmweoi9bbqg',
#  'iphonethe confession app spend time confessing faith need le time confessing sin much',
#  'day 32 p love iphone photography book flickr httpflickrp95jthk',
#  'hey apple want say fuck u ur new updateit took 3 hour download hate apple ios7',
#  'photo sunset westcoast iphone taken instagram huntington dog beach httptmblrcozjccsxgkygn0',
#  'added httpwefollowcom twitter directory newyorkny iphone fun education mom',
#  'iphones losin phone reception got 6 text n 3 missed call last 30 min',
#  'tmobile day come thanks jump finally get rid iphone get samsung note 3 absolutely love tmobile',
#  'get taste frank ocean ’ new… httpdlvritlyqjtp news photography fashion health fail tech ipad iphone funny lol',
#  'annoying finish level wheres water buy full version apple',
#  'nothing wear important smile smile quote mood girl bos blog life style amazing quote wcw wce bestoftheday cute pretty beautiful sexy fashion babe samsung wednesday funpictwittercomggnuvxbv42',
#  'natepgilbraith send text turn imessage',
#  'fanta apple fanta delish sunday sundayfunday healing so… httpswwwinstagramcompbfcyrndvbb3',
#  'wont sleep way lap babygirl popular iphonesia iphone4 iphone babygirl ios5 httpinstagrampxuunu',
#  '’ loverly tweet rabbitsofinstagram bunniesofinstagram rabbit hop bounce charlie houserabbit bunnylove rabbitsofig shotoniphone apple iphone7plus photography photographer family chuck charles httpsifttt2idypb3 pictwittercomgpw3nfuzwh',
#  'new iphone case happy valentine day iphone case le lucien swarovski crystal pink httpinstagrampg9cdiorcd5',
#  'photo vegan glutenfree apple pie day silly sally ’ pop diner httptmblrcozyuirs1wadbou',
#  'technology advanced day syncing ipod hear 8 second mmlp2 song fml',
#  'sweet iphone 3 sweet phone iphone apple candy fun cute beatiful beaty gold good nice photo fo httpvkcc2jm1tb',
#  'wait finally hand iphonex iphonex iphone10 spacegray 256gb apple pictwittercomogo7gkeopw',
#  'unpacking sony xperia z5 compact android really really nice first impression httpowlyxc8zx pictwittercomblo98b8osu',
#  'muoneoz progress bar 1 car key long give another hour still 1 car key cold boot fear itll dead',
#  'siri doesnt understand command lol beautiful funny nephew allshots iphone igers siri httpinstagramps0fopgbmrt',
#  'endless love instagram instagood instadaily instahub instagood photoofthaday iphone iphone4 httpinstagramps00omtqk6a',
#  'literally cry lost contact',
#  'andyvaughan look great wonder available uk b compare apple cloud',
#  '¡al fiiiiin laptop sony vaio white black case minnie beautiful inlove… httpinstagramcompxlclaievxt',
#  'dear blackberry occasionally best fruit fall tree dont worry thou soon best fruit',
#  'username：splinkio httpcurrystagramtk thai curry yum food iphone iphoneonly iphoneography picoft',
#  'yosemite steep hill climb mac kernel issue 7 hour serve wellapple update',
#  'another fuckyou sony ps3 health warning display upon boot',
#  'brbrrylove13 shesh told ya stop killing mojo p 33333',
#  'spend like three hour finally get thing ship new phone selfie samsung httpsinstagramcomp8va22yzwy',
#  'advertisement new samsung galaxy gear vr well made commercial feeling httpswwwyoutubecomwatchvmn6jfwo6eu0featureshare …',
#  'lost picture everything phone past year sodepressed samsunggalaxyftw loljk',
#  'check jewish american single free paid membership available httpowly9z1vk jewish single iphone app',
#  'follow capetownsup instagram httpmfttsoajg sup surf fun capetown funny sexy samsung pictwittercomoz6d2134xt',
#  'final cut pro trial doesnt work yosemite aarrrggghhhh fail makingmylifesodifficultpictwittercomlzs9zgi7sb',
#  'really apple delete half downloaded el capitan first mistake usefuckingtorrent',
#  'hooray stuff arrived excited case android samsung galaxy today open now… httpinstagramcomppfteojwqw1',
#  'really need new iphone charger mine spaz short constantly piss like apple iphones',
#  'phone officially broken hear go screen doesnt work keyboard okay though samsung',
#  'deepeshalways ndtvgadgets enough money challenge u jury decision simple an mine apple',
#  'golden state warrior photooftheday instadaily like iphone follow colorful style… httpinstagramcompx2rz7vltw8',
#  'reinstalling itunes 12th time week refuse sync phone',
#  'slept new iphone last night im love iphone atlast',
#  'father son samsung live laugh life instago instahub instamood instagood… httpinstagramcompe3j48khhk9',
#  'happy bday jj bday jj crazyfriend iphone party lb l4l likeall likeback… httpsinstagramcomp2wkfobkbd',
#  'pic day quote wisdom word smile follow ortho cute iphone fashion makeup brace httpfbme2z8wjtvhy',
#  'want love match iphone buy lovematcher httpitunesify9wz iphone',
#  'nice one valentinesday playstationasia ad ps4 february playstation sony gamers college… httpinstagramcompyzghrgmilt',
#  'portrait shot sonya6300 sonyalpha sonycamera sony sony35mm 35mm dof bokeh market markt hemd schwarz blacknwhite blackandwhite grey smile … httpswwwinstagramcompbmvdw9ije8gutmsourceigtwittershareigshidsk8n6sz2rvku …',
#  'hacker wifi password httpsgooglfnvsfj android apps beautiful cute color igers iphoneonly iphone',
#  'extra zoom video httpsgooglvicmvz android apps beautiful cute color igers iphoneonly iphone',
#  'phone deleted every single one contact random apple',
#  'love new baby ipod music apple itunes gold httpswwwinstagramcompbhamapkj47n',
#  'one stevejobs tyrannical reign apple fucking cultist',
#  '400 follower thanks yall inkstagram iphone instagram addiction wordphoto httpinstagrampium0o4yprg rt mdotroche',
#  'prophet husband iphone httpifttt2bor0kb android httpifttt2asurcj kindle book february 01 2017 a…',
#  'upgraded 5 \uf8ffiphone 7 apple iphone7 iphone instadaily instagramers instalike… httpswwwinstagramcompbkye6blru',
#  'help deliver happiness 2000 child httpbitly1c9vihd malaysia uai samsung sony toyota',
#  'there something wrong charge phone least three time day getbetterbatteries',
#  'new samsung galaxy tab4 like real bæ tablet smile',
#  'santa visited wife earlier year see iphoneonly iphone sweden… httpsinstagramcompqujdfqbs',
#  'hi world old photo followme like4likes good dog solodivertimento samsung… httpswwwinstagramcomprqvnhoa2l',
#  'marque gray swag swagger sky dog cat iphone new followme edit sick paint minnesota gopherspictwittercomi9ldh1lxwg',
#  'geniusbar suck tube surgery bullshit apple may good product customercare battery',
#  'happy ps4 sony playstation gta5 fun design white dualshock instaday cool… httpsinstagramcomp15cr0aree',
#  'holy shitbirds watched last night colbertreport apple presentation iwatch creepy asidk',
#  'book good night relax cool perfect book iphone preguntaleaalicia instaphoto httpinstagramcomphz7yxkga4y',
#  'photo prosperous new year everyone welcome 2015 newyear art drawing sketch samsung httptmblrcoznnqeq1zqeqm',
#  'one blog video girl amazing fashion ootd beautiful samsung swag videoofthedaypictwittercomp7ln5unh7y',
#  'new iphone o 3g fucking suck want throw phone wall sm app crash apple iphone',
#  'baby let love adorn miguel fan artdealer samsung hospital braid smile… httpinstagramcompcw3qb5ifgb',
#  'photo 5 sign peace sign junephotoaday photoadayjune body iphone likeit taken httptmblrcozw2twxmqobg',
#  'would delet photo vids concert mylifesajoke',
#  'nobauerm let get hooked fast w iphone u fall promise',
#  'take evening update two apple device hate itunes hate apple android next round apple',
#  'audi offer apple android smartphone integration 2015 httpowlyywvh0',
#  'ran buy iphone charger middle night iphone charger iphone apple',
#  'havent used apple product year hole accessed old account cant find way dispute charge',
#  'photo pic day quote wisdom word smile follow tweetgram cute iphone fashion httptmblrcozsf7et103raem',
#  'new york baby new york amazing city big apple summer httpinstagrampm4p7xnjgp0',
#  'chasing pavement story friendship family music life destiny soulmates kindle nook iphone ipad ipod',
#  'irishazada love photography go follow photograpytrick tweet awesome sunset photography iphone htt',
#  'like share want car accessory bag iphone samsung httpsbestcheapphonescomindexphpproductnewqualified1pcautocaraccessoryhangingbagdrinksphonesstoragepouchholderslevertdropshipdig638 …pictwittercomxhwknjqfyh',
#  'apple suck every time update o erase private info disable apps purchase like ’ customer friendly approach time go android disappointed',
#  'goodnight dubai sweet dream life hope joy dubai uae iphone instagram httpinstagrampura7vjjs6h',
#  'birthday present came advance thank much apple ipadmini iphone5s lucky httpinstagramcompm48phiyruv',
#  'saturday everyone look shop great deal dvd bluray vdeogames ps3 sony playstation httpstoresshopebaycomlttreasures2013',
#  'turkey photography photo travel nature photo landscape photooftheday camera sony pic foto passion behappy pictwittercom0mjjnomhpy',
#  'amigo friend iphonesia iphone instagood instagram photooftheday tweegram … httpinstagramcompb7l534ban7',
#  'thing make reading pink ereader sony use nearly… httpinstagramcomprlypkzcmni',
#  'edm life hardwell amor apple avicii acedemy academia b2b bogota mac music… httpinstagramcompztka70zd3b',
#  'year shuffle samsung galaxyfamily finally real shuffle like whole new playlist',
#  'thank u much \ue022\ue327 god christian iphone instagram iphonesia pray thanks popularpage \ue32e httpinstagrampxqaqf',
#  'woohoo finally get nx1000 finally camera nx1000 samsung excited nice black peace tha httpinstagrampsa8bnzddg',
#  'family family friend beauty fun cuties iphone iphoneisa foreveryoung hookahbar onyx… httpinstagrampvkkxyhsyk6',
#  'happy samsung galaxy note2 got updated android kitkat version 442 thanks samsung mobile',
#  'rt sleekdeals hot deal high tech lightning usb cable 3 foot 495 1999 80 geek tech bot deal amazon home iphone ipad android samsung galaxy google gadget gift io technews power pc dev …pictwittercomykfpf2fixe',
#  'looove amazing beautiful copenhagen creative composer denmark fun f4f hot iconic keepthefaith l4l mariajensen music original pop producer red rock soul singer songwriter song universal sony warner worldpictwittercomjrdwetxbjo',
#  'bad sprint doesnt carry lumia device least able pick samsung ativ neo windowsphone',
#  'would like wish amazing day make every minute count tl today iphone accessory news life july 10 2017 0700…',
#  'ipads new home ipad leopardprint neon ipad3 apple httpinstagramcomphqkb2ssujl',
#  'iphone apps listen drive time hip hop nyc whilst peeling potato kitchen',
#  'dissatisfied apple iphone6splus runner issue filter camera sweat incasearmband',
#  'love fuck outta kingponder6 imessage iphone text gay hesa httpinstagramcompaitqo5r6la',
#  'ready chromebook samsung hellokitty diamond shine ready httpinstagramcompjnmhgynfq',
#  'beach group text beach ocean cellphone friend trio iphone cosmosquito karebear5891 httpinstagramcompfndf5bp6lm',
#  'last apple watch 42mm space black stainless steel excited overthemoon didalittleweepictwittercomzznj908fjw',
#  'l ny hug follow like iphone tattoo christmas beautiful newyork httpinstagrampcyraz',
#  'slick1913 mindy0x id totally fuck siri knowledge excites siri fuckinsiri',
#  'lol love iphone rtto apple fuckedup iphone4 u know u get oh yes pow via kadaf1',
#  'photo new macbook air installed ready perform apple pepsimax ddb taken httptmblrcozxq6zysnslur',
#  'throw worry fit fab marjdiary samsung fit fabolous smile stayhealthy… httpsinstagramcomp1e96moblcz',
#  'samsung galaxy s9 plus dual sim g965fd 6gb ram 256b black httpzprio6psxm httpzprio6nxjm florida money today life twitch retweet twitter birthday sale android window nokia samsung iphone phone smartphone motorola lg sony offer best',
#  'new phone yes please without phone death taking hold sony sorrysamsung',
#  'speed wifi3g4g 2016 httpsgooglqmdlxq android apps unitedstate cute color igers iphoneonly guitarplayer iphone',
#  '219€99 samsung gear s2 etat comme neuve samsung gears2 prixhappy occasion cash… httpswwwinstagramcompbirlqnjggo',
#  'applenws iphone would trade computer smart phone galaxynote sexy',
#  'mac o httpmailapp hight sierra buggy little crap jobsdead applenofuture',
#  'send calendar event invite exchange user user cant accept icloud v exchange apple iphone',
#  'like iphone get play game lol love angry bird iphone gam httpwwwlinkaticomqindexphpi666227',
#  'phone keep freezing whenever go end call iphone',
#  'ever since updated phone fucking apple iphoneproblems appleofficlal',
#  'chicwithatwist team ootd mixandmatch urban style expressyourselfie workshopping samsung galaxya httpfbme2qi5n7kce',
#  'ive trying 2 hour sync ipod give',
#  'conversation sister wouldnt swap sister text imessage iphone chat… httpsinstagramcomp5ldm7ihp5',
#  'small blue — steemit httpssteemitcomphotographyfoxkoit6pj2fasmallandblue … blue small life story blog try nature naturephotos bug blue color color photo photo photography sony sonylens lens sonyphotography image image photofeed feed follow home gr grassland land',
#  'photo oh yeah caligurl619 pretty cute gorgeous beauty ig iphone ignation instahub httptmblrcozonpawppu4k',
#  'bought something kahapon walkman sony xempre orange headset haha',
#  'shadesofmoonlight dress party alcohol night heel iphone leg stripe httptmblrcoztkuvc8ht9s',
#  'actually cry couldnt screenshot snapchat lock button broken apple',
#  'egg speaker speaker egg awesome music ipod apple school chilling relax … httpinstagramcompdw4bmwd6ch',
#  'reallyreal app approved iphone ipad dating college httpreallyrealcom college vc singlepictwittercom0d9dzq0cxo',
#  'mychristmaswish last year wish come true course fame friend chocolate food iphone',
#  'swearif iphone update erased everything phone im gunna flip shit',
#  'yes itunes take time put song ipod wishishadagalaxy',
#  'rose27moon trying help iphone majority usa help adore',
#  'getting email picture like make life iphone instagram nofilter cute christmas popular httpinstagrampxp6b1',
#  'iphones wallpaper much full constellation milk way annabelle09472 shermaine417 want bump',
#  'drink amazing fruit apple cherry purple tasty drink sun garden httpinstagramcompdwai0rliea',
#  'blocky car httpgreenrobotappsnet4055blockycarssozdaygonochnyybolidhtml … андроид android game news io apple iphone',
#  'hey guy look newmotorolamotoext15242ndgen8gbsimfree httpzprionv7mc money today life twitch birthday sale android window nokia samsung iphone phone smartphone motorola offer bestprice jun 16 2018 0200am',
#  'cant unlock samsung galaxy ace cause good blackberry although managed unlock samsung vodafone',
#  'look mommy got 4 p igers ipad apple mom gift instahub instadaily blessed fo httpinstagrampuor2uoh6c0',
#  'apple could make itunes itunesradio bit would fabulous disappointing',
#  'finally iphone dominated iphones apple io android iphonex market chinese smartphone httpstechinwirecom20170921finallyiphonewillbedominatedbyiphones …pictwittercomgrc1o4hbsc',
#  'apple hate rant iphone synch outlook entourage darthjobsstrikesagain say apple closed system',
#  'good morning everyone jam nike iphone apple 5 goodmorning selfie coffee httpifttt1x9vo4a pictwittercomhwxpuracjl',
#  'rt genevievermrz picture smileykidd13 tennis today tennis babolat pink iphone black gold green r http',
#  'photo apple ipad iphone imac ibra samsung galaxy instragram instramode smiling httptmblrcozxqgpvvkqxyh',
#  'senza love without nasimibeach compleanno birthday hb apple sun iphone… httpinstagramcompoufklyxewb',
#  'dear apple thank selling 2000 dollar laptop date 4 year able run diablo3 p',
#  'convenient iphone stopped working completely le 3 month warranty ended mad apple',
#  'purpose life live life purpose mondaymotivation httpsitunesapplecomappid1131238793 … iphone ipad io mondaymotivation',
#  'paris iphone photo chronicle violence horor httpbitlyaixqfo paris iphone poster wall einstein answer',
#  'apple rolling verizon iphone valentine day httphtly3wdfl sale',
#  'bobinson twitter tehran photography affliate marketing iran iphone ruby obama osama saddam iraq google adwords',
#  'happy new year 2018 newyear reveillon2018 happynewyear2018 newyears year 2018 nouvelleannee nouvelleannée instagram instagram2018 web webmaster webdesign elodiewebdesign apple mac macbook macbookpropictwittercommzcxkjuwqf',
#  'sunday im tranna cram work sunday mac macbook samsung s3 mom work life httpinstagramcompccpg62kvvh',
#  'hi apple thanks 160gig 136 retarded fuckup recycle free apple iphone headphone nah io whatev',
#  '204 lmprodevents present stage home show pop musician rock hardrock sound live sbamfest festival italy torino turin guitarpractice gig event music guitar metal stratocaster apple iphone socialmedia club sneak life band rt webzine ffpictwittercompmivqqvdxy',
#  'learn smoke smoke painting iphone art life green httpbitlyvcvbvx22 inocentes',
#  'indulge swim tomorrow allamerican seasonalcrisp appleblueberrylemoncaramel 4thsee beachwere closedmonday',
#  'gunslugs 2 httpgreenrobotappsnet3900gunslugs2mezhgalakticheskayaoperaciyaspaseniyahtml … андроид android game news io apple iphone',
#  'havent tried instagram yet here reason give whirl httpowly4xgwd iphone',
#  'delicious morning friday smoothie nutribullet tasty apple orange banana honey by…pictwittercom0wautkfgi8',
#  'dont wait long another apple fail come along itard appear',
#  'reflect iphonesia iphone instagood instagram photooftheday tweegram iphoneonly far far away httpinstagramprbriyeg9hz',
#  'hi new phone cover ebay blue tower samsung httpinstagramcompeswo8llr',
#  'alternative power fix apple cinema display 23 priceless take random 24volt power connector finish easy pictwittercomycug9wjopq',
#  'new phone iphone iphone6 new phone mine silver white exciting httpinstagramcompx4joelpmaq',
#  'thanks oneplusde oneplus still providing update oneplus3 android never experience mobile oneplus',
#  'iphone doesnt seem confederate flag emoji little flag section change southernmen ga al',
#  'photo new addition family instapic life samsung s4 april spring cali httptmblrcozbpr6o1egs8g',
#  'fucking apple man wan na use wifi youre telling 1999 6999 use wifi apple',
#  'take look samsungs cool see dream initiative httpwpmep2oq8i3ew samsung iseeyourdreams soccer kid fun',
#  '1 hour usage phone 13 thanks iphone apple',
#  'tablet using google android system accounted 565 market apple io achieved 396 androidalltheway',
#  'downgraded phone backup arent compatible version retained phonebook going upgrade',
#  'spell check mistyped quickest quackiest alternative often people use word',
#  'dude 4th usb chord thats broken past 25 month',
#  'one newest model iphone iphoneography tumblr tweegram instagramaddict life thingsilove httpinstagrampcmiwz',
#  'new samsung galaxy advance case get best friend madelief98 thank … httpinstagramcompbdcfwzxxh0',
#  'yey thanks dad xperia sony z2 xperiaz2 gift graduationgift httpsinstagramcomp1242j1suxm',
#  'follow capetownsup instagram httpmfttigmdr sup surf fun capetown funny sexy samsung pictwittercomttjru6zxzh',
#  'anyone else trouble iphone update taking age run new camera stuff',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow åfä',
#  'welcome world iphone 6 iphone6 iphone apple life cny httpinstagramcompzcbixymc78',
#  'cant iphone block number call every day ppi etc possible old nokia',
#  'hey appleofficlal schedule appts yall never honor never time frustrated theirempsareemps',
#  'uninstall samsung ky get android file transfer working macos option worked',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow rfj',
#  'photo yea bro fifa day dope iphone instagood instagram ps3 picoftheday instaphoto httptmblrcoz9jsxubwk0m',
#  'finally get something apple american dont gethttptinyurlcom29v5d2m rogers bell telus',
#  'fib rhyme sib nib jib bib rib dibs start today httpbitlyrhymeapp rhyme iphone',
#  'oneplus5 finally fixed fast efficient thx 3 oneplus',
#  'thought would fun jailbreak ipod im sitting restoring factory setting apple jailbreak',
#  'love fucking ipad rednose musicevideo blackfriday walmart apple ipadmini httpinstagramcomphsvbqf5cb',
#  'people iphones keep showing',
#  'follow capetownsup instagram httpmfttrzwi4 sup surf fun capetown funny sexy samsung pictwittercomgfkco06mqm',
#  'photo meanwhile twitter… samsung galaxypocket samsungcheerdance blessed ’ instafun httptmblrcoziqpmytfoco',
#  'samsungmobileus honored using 5 first ever stock mine stockpile im thank samsung stockmarket stock stockport stocktonscholars investing apple stockpile samsung positivevibes stocksmarket investor investment',
#  'happy mother day mom mothersday iphone igdaily instagood iphoneonly bestoftheday… httpinstagramcompzolbqitfu',
#  'rt lorimoreno im married go rt sharonhayes healthy dating there app httpcotag8xtzo9 iphone',
#  'follow capetownsup instagram httpmfttkpv5o sup surf fun capetown funny sexy samsung pictwittercomodosytgabd',
#  'cant iphones option change font like want cute girly one thats option sorry ugh',
#  'using loving instagram upgrade introduces powerful new feature httpjmpw2zrmf iphone app',
#  'apple iphone x apple iphonex techjunkie tech iphone upgrade youbeauty beaut… httpswwwinstagramcompbb4gyutdvai',
#  'reason id get iphone bc supercool case especially one bottle opener back',
#  'solid gold retro christmas video httptinyurlcom22lu259 ff friend gratitude ipad iphone blackberry entrpreneur',
#  'yes finally got nougat update samsung s7 edge woke battery using 3 slept compared 1015',
#  'unboxing new smartphone op2 oneplus2 oneplus amazon excited wala feelingpictwittercomcschj4erex',
#  'small garden — steemit httpssteemitcomphotographyfoxkoitmysmallgarden … small garden home life look story photo photo photography image image wow cool like sony sonylens sonyphotos sonyphoto sonyphotography photofeed feed new top colorchallenge',
#  'new video youtube subscribe daily vlogs twitch gaming twitch ps4 xbox sony game destiny2 dancehttpsyoutubewlk1ssndguw',
#  'hate phone ipod take battery much iphone',
#  'new oneyey babypink pink otterbox samsung s2 phone phonecase cute new httpinstagramcompzsayuwmipn',
#  'would like wish amazing day make every minute count tl today iphone accessory news life june 12 2017 0700…',
#  'water summer summertime pool countryhouse countryside xperiaz1 sony httpinstagramcompsfbdhcn8dz',
#  'im trying instagram iphone4 iphone iphoneography imissyou longdistance sad httpinstagramph3jlrwo1q',
#  'first yellow — steemit httpssteemitcomphotographyfoxkoitfirstyellow … yellow nature color color new story blog photo photo photography image image sony sonylens sonyphoto sonyphotos sonyphotography photofeed news top wow cool like look color colorphotography',
#  'good woman might iphone smash phoneunlocking motorola india uk canada kenya smartphone motorola wikomobile europe france relationshipgoals… httpswwwinstagramcompbm114xxhmhkutmsourceigtwittershareigshid1difrvki544rs …',
#  'anyone know ipod wont turn tried charging nothing hateapple',
#  'munchhhhhh chocolate instagood iphoneonly iphone dairymilk cadbury oreo tasty girl httpinstagrampra2w9ne4dn',
#  'tell u supacamx amazing new live camera effect app iphone',
#  'new cellphone case samsung galaxys3 cute case rilakkuma bear new phone super httpinstagramcompathdyxsjce',
#  'headphone sony red headphone music igerspiura c c real plaza piura httpsinstagramcomp9arbamnvu',
#  'photo healthy balloon survivor haha agoogler googlemmi google colorful motorola fun httptmblrcozjezuyuaczbz',
#  'photo iphonesia iphone instagood instagram photooftheday tweegram iphoneonly igers httptmblrcozz7xpxpqmwkt',
#  'get new ipads one care map mac',
#  'night day split night day effect science iphone valencia spain picoftheday photooftheday evening httpfbme1tdwgtvfz',
#  'finally oneplus3t arrived excited thanks oneplus oneplus brandnew cellphone httpswwwinstagramcompbqtl2qklbwz',
#  'awesome friendship best otherhalf iphone imessage biff text httpinstagrampvkdrpyo0ud',
#  '1 get anyone help applestore everyones busy 1 say hello procedure wait helped',
#  'snapdeal used order soemthin every alternate day see u sent defective sony tv bro',
#  'phone plugged night long didnt even charge annoyed',
#  'since iphone didnt come went got earpods … httpinstagramcomphzbbsfmmjm',
#  'cooge beach 2014 hafizh instamood like4like samsung camera instaphone cooge beach… httpinstagramcompvthd2adh',
#  '“ drshwetapuri apple working iphone 6 running ios7 wasnt iphone5 flopshow enough reason p ” hey fan',
#  'lol nicked rt iamnickd say hateapple android picoftheday photooftheday insta instagram httppostsujyie',
#  'baby finally got newphone galaxy samsung smartphone android galaxys5 tmobile httpinstagramcompng7k1ukd7i',
#  'wrap fish mexican mercatometropolitano londonfoodies london diningout market indoors instafave igdaily instagood photooftheday vsco photography london iphone httpifttt2jijsqx ifttt instagrampictwittercomqhrdo4b5rm',
#  'iphone bugging like 3 day finally back track though start catching tweet soon much love',
#  'follow capetownsup instagram httpmfttp5jmd sup surf fun capetown funny sexy samsung pictwittercomg5pyufti6v',
#  'highlight week neues smartphone httpwwwerdbeerchentestetcom201711highlightsofweekneuessmartphonehtml … smartphone huawei samsung baby handy neu handykauf pictwittercomvvus6eabjy',
#  'cristianacarpe followsunday followback rt teamfollowback follow retweet iphone keep ya thing',
#  'change finger id every fking day want feature recently thats im officially thebrand notthefruit',
#  'fur ball dog rescuedog cutenessoverload photooftheday instagood picoftheday on1pics sony … httpswwwinstagramcompbbdshocfnjo pictwittercomdw0dlvo3up',
#  'top photo app available httpsitunesapplecomusapplove360id809353957mt8 … photography usa woman poem valentine iphone kärlek 872',
#  'hate apple twitter app doesnt work anymore bcs ipod old new update apple',
#  'went apple store got back iphone replaced',
#  'summer time sonya7ii family photooftheday cute capture followme beautiful prilaga photography picoftheday instadaily sony sonyalpha allshots film photo fashion fullframe girl artpictwittercombas1ejzfct',
#  'future cell watch awesome samsung android phone watch followme cute me… httpinstagramcomporthhbrpg',
#  'bonding time rakim106 sexychelly orangecafe apple miglight friend httpinstagramcompfeccultagg',
#  'finally got macbook finally apple mac macbook computer firsttime excited laptop lulipeacepictwittercom1ba2dhyuad',
#  'litetally one week iphone 4 fuck yes',
#  'iphone sexy girl ohmann hab ich langeweile nerd',
#  'redeem promocode io iphone game playing free today art indiegame unity3d art puzzle fun httpcodehookupcoma1e260ab pictwittercomnxtrvqdwpo',
#  'love cat cat cute cool likethisphoto instaphoto instalike iphone iphonisia jj… httpinstagrampvkpsgeai3n',
#  'summer 2015 burgundy sunday afternoon smile picoftheafternoon ig sony… httpswwwinstagramcompbp2ovyih6ye',
#  'apple fucking stupid pay 35 plus tax get help phone telephone apple',
#  'prophet husband iphone httpifttt2bor0kb android httpifttt2asurcj kindle book march 19 2017 1…',
#  'funny story picking apple laughter laugh smile applesauce summer apple harvest httpwwwgodsgrowinggardencom201407myhubbymakesmelaugh2homemadehtml …',
#  'time come bride sister sony proud family indonesia jakarta grand asia… httpswwwinstagramcompbiojkyjaxmy',
#  'look like andrewmccabe going prison thejoint thebighouse apple cigarette theyard thepokey bigbobbasmansion get ready hardtime douchebag vaseline lipstick fuckedinthe prisonbitch lockandrewmccabeup loser as',
#  'phone freaked picture note',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow hrhp',
#  'iphone 6 pricereduction touchid 4g nfc contactless payment httptiddly714ce86b tech mobilepictwittercom6hpz87xfzn',
#  'excited little arrival today samsunguk samsung gearfit2 freebie healthstartpictwittercomi2sy8gcelm',
#  'iphone itunes pissing might well restore whole phone start right hateiphones hateapple fthis',
#  'happy friday sticker app preview promised enjoy —— “ bright boost ” appstore sticker io imessage iphone ipad family friend gifpictwittercomyz5ttdswpv',
#  'finally iphone shatters 1 month contract wehadagoodrun',
#  'furrtree nyc ny vscocam vsco sony sonyalpha a7riii 35mm manhattan nike… httpswwwinstagramcompbfhmqxig5uj',
#  'roast pork definately apple sauce steamed veggie mash menu evening scrummy double s oh far im concerned cheesefreak sauce well veggie sunday',
#  'waiting wait cute afternoon iphone picfortoday dog chiwawa… httpinstagramcompdy9zhfrzdj',
#  'brad boxberger nearing return ray news photography fashion health fail tech ipad iphone funny l…pictwittercomneh35cbqwp',
#  'pretty amazing feeling phone ’ need charge day iphonex iphone6sucked apple theshit',
#  'good free fruit woolies woolworth banana apple orange fresh… httpswwwinstagramcompbaeno54sk3h',
#  'apple brings thing want course magickeyboard',
#  'happiness make better person kiss girl pic samsung photooftheday httpinstagramcompftibhjnpra',
#  'cute heart custom ipad iphone case valentine day httprewards4lifegiftsposterouscomlovecuteheartscustomipadandiphonecase … via rewards4life',
#  'refreshing fresh salad take enjoy meal apple io smartphone… httpswwwinstagramcompbqnt4tasar',
#  'iphone 8 plus “ iphonex user experience nightmare ” httpswwwfastcodesigncom90150025theiphonexisauserexperiencenightmare …',
#  'library paula vogel news photography fashion health fail tech ipad iphone funny lolpictwittercom0yk3fbch0c',
#  'say hello new camera sony fs7 videoproduction filmmaking sony fs7 bts httpfbmeoux3pcid',
#  'happy fit style friday money samsung wels österreich lifestyle herbst… httpswwwinstagramcompbz6ehxnlneg',
#  'moschino iphone case new baby inspired inlove fancy fashion luxury boylikeboys… httpsinstagramcomp4poufyk4ew',
#  'black outing wednesday dont think bad gambateh note samsung asian yans lovely home httpinstagramptaz39suw',
#  '10pcs exquisite squishy random charm httpebayto2yi9mr7 iphone strap toy decor free shop style sale today giveawaypictwittercombpgjry4g0e',
#  'iphone 16 iphone apple avtweeps avtweetup hot follow friend summer httpsinstagramcomp29wqogai0u',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow ff 7fl',
#  'loving cake day brighton got propper lush chocolate beetroot cake apple cake chocolate raspberry cheesecake plus butter shortbread biscuit go coffee fancy',
#  'new tv bedroom happy samsung smart tv new httpinstagramcompxheswylubp',
#  'last day vote dabball round httpowly6dt62 art game app iphone ipad itunes apple karma bribe browniepoints',
#  'absolutely love sony music cam recommend sony musiccam viola photobyclementino… httpsinstagramcomp3emkscxanc',
#  'dont get iphones popular theyre pure shite android far best smartphone',
#  'hate iphones impossible use 3g lte theworst cantdeal',
#  'hateapple update didnt work causing computer restore ipod fml',
#  'scroll twitter facebook like 20 min phone go 85 63 seriously iphone iphone batterysucks',
#  'came home mac case front door winning apple pink matte frosted',
#  'installed icloud computer wiped outlook contact calender',
#  'coming soon human hue apparel humanity goodvibes apparel fitness fashion igers streetwear skate surf iphone sport tgifpictwittercomoifg1dpxr7',
#  'seriously migration assistant seamless fml firstworldproblems apple epicfail',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow znjq',
#  'follow capetownsup instagram httpmfttwiekf sup surf fun capetown funny sexy samsung pictwittercomoiajffndhv',
#  'word fuck still turn duck iphone swear fucking know better pottymouth',
#  'wind tree haveaniceday french mothersday timelapse shotoniphone iphonex httpsifttt2xgvnsv pictwittercomldt6gse4g2',
#  'sunflower make nature flower sunflower yellow summer sevastopol samsung nxmini httpsinstagramcomp6a6anaj0a4',
#  'razr d3 new estreno motorola razr razrd3 felicidad smile emocion instapic httpinstagramcompdvtejdpo5s',
#  'iphone 6 totally amazing iphone ios9 apple amazing phone tech music iphone6 plus gold mobile',
#  '“ drshwetapuri apple working iphone 6 running ios7 wasnt iphone5 flopshow enough reason p ” eh',
#  'love bff friend brazilian cute fashion mylife tweegram iphone instalovers photo httpinstagramporgjtbws6t',
#  'warning poke sleeping giant httpgfycatcomastonishingdearappaloosa … cute aww rt ff iphone android',
#  'new lock screen home screen hehe lockscreen homescreen iphone6 iphone everyminute lifepictwittercomgqvkyno2ax',
#  'great pointless apps dont even want taking storage space dont even thanks apple',
#  'drinking coffee reading httpbitlysimplebiblerox free iphone app jesus awesome god godbless',
#  'aww thank much msharlem nowplaying wake next 2 savvysossa downloaded uploaded iphone',
#  'applenws apple shitty io 6 made everyones phone suck as',
#  'good tab back 2 week samsung tablet httpinstagramcompk2ijljxvb',
#  'hateapple wasted 35 hour life paying 29 get new battery iphone rigged drain battery life apple thx time switch android iphone6s',
#  'going back iphone seeing fund added account httpcashthevisitscomindexphprefcode8223 … workonline cashregisterrip',
#  'new hoesje samsung galaxy lll vistaprint affie white lv httpinstagramcomphiogcdvmf6',
#  '༺☾➊☽༻ retweet ༺☾➋☽༻ follow rt ༺☾➌☽༻ followback ༺☾➍☽༻ gain rt now༺☾➎☽༻ iphone sougofollow ff 98ä1',
#  'nickii orange pictureoftheday samsung samsunggalaxys2 galaxy s2 blonde haare… httpinstagramcompb87dmkol35',
#  'swear god im going throw phone fucking bus doesnt stop lagging every two fucking second ios7 apple',
#  'apple messed made new charger iphone 5 really messed using 6 iphone6 apple',
#  'oh hi baby new phone finally samsung galaxys5 excited abouttime yaay baby… httpinstagramcomppwf4sztrn8',
#  'josalmon hammerand shotgunand load green paint splash pretentious store donotfallfortheirlies',
#  'use iphone htcuk one go 4th repair hopefully straightforward replacement time',
#  'funny thing doesnt window sue apple copying apple one allowed teamwindows teamandroid',
#  'hateapple trying get newer version wayl nothingworkswithme',
#  'know im going love galaxy s3 stoked samsung byeiphone',
#  'yeah finally samsung galaxy s3 samsung s3 white httpinstagrampub6jpnfavk',
#  'picture phone dunno thought looked cool picture memory 1000 iphone httpinstagramcompesq2djpdqo',
#  'hooked ipod da fuck music go',
#  'leftocentre gaycarboys slsandpet capitalteacher gusfaceredux hey thats type iphone',
#  'working hehehe america instagood selfie mac apple coffee vidadura verynice… httpsinstagramcomp41rr1syqu',
#  'youtubesubscribe daily vlogs twitch gaming fun ps4 xbox sony game bungie destiny2 destiny ignhttpyoutubey2ngwbsosi',
#  'follow play jhawk iphone ipad ipod free game fun kansa georgia httpinstagramcompm7rvjeean7',
#  'apple family garden 100happydays day42 apple garden ly flower kitchen httpinstagramcompsns4sqtxcr',
#  'upgrading imac lion made smile im really httpowlyiftcd max memory 16gb apple fastandfurious',
#  'steve job god world wouldve addicted technology anyways tried give better version steve',
#  'new case lurv new case iphone selfie summer instgram hot 2015 wait… httpsinstagramcomp4rivohlsl',
#  'new phone setup last could also explain absence evening lol nice shiny iphonex get used larger screen smaller phone compared iphone 8 iphonex apple pictwittercomd6hb9npg4f',
#  'mac o x 1068 io 5 beta 2 itunes 105 beta feel fresh n updated set lion set ios5 itunes apple',
#  '29 mac o x 107 one moment wallet ill come back minute wwdc apple osx',
#  'fuck hate itunes garbage program using windowscrashes doesnt find device apple',
#  'live rizkyff rzkyff holiday forest dreamer lightroom adobe sony jakarta indonesia instaday photoshoot photography instagood followme photooftheday … httpswwwinstagramcompbkhkawshlwutmsourceigtwittershareigshidqqc3xol0gb1j …',
#  'molecule rhyme cool pool tool mule jules pules donts miss httpbitlyrhymeapp rhyme iphone',
#  'happy valentine day czarinagizelle samsung s3 heart day couple phone red favorite httpinstagrampvrcbfnk9g',
#  'chicagonow httpwwwchicagonowcomtakingasecondlook201110tofeelitistoflyatleastwithyouriphone … exactly cosmic yet concrete force flight life iphone mri brain',
#  'kierannisbet dont think haha staff rude letter lengthy one rant btw sorry hahahaha',
#  'ⓒ check new flappy bird highscore flappybird highscore iphonesia samsung galaxys5 bird gamepictwittercomvk6vhmkfy9',
#  'sony xperia z2 unboxing newphone freeupgrade sony xperiaz2 sexybeast excited gadget newtoy httpinstagramcompnf3h6nh1z',
#  'michelle came home httpowly2uxzl tcot nascar theater movie single ipad iphone windows7',
# ...
#  'iphone twitter update feel way better use faster',
#  'conversion photo video free httpgooglesdqpv android apps beautiful cute color igers iphoneonly iphone',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow nyv',
#  'waiting iphone 8 iphone iphone8 leak rich iphone8plus apple applestore stevejobs 11september samsung iphoneplus',
#  'new sleeping bag pad present marcjacobs ipad apple beaut instaaddict instafashio httpinstagrampqzbtc6y7t5',
#  'bighope allah pray life hope samsung instagram facebook twitter photogrid notcry httpinstagramcompjuien5rdt',
#  'apple saved itunes account guy apple customer support great thank bharat apple apple awesome',
#  'photo quote heart world thinkpink boy girl world pictoftheday photogram iphone httptmblrcozvzsufak3am',
#  'preggy sister busy new note8 android samsung galaxy excited teacher httpinstagramcompfxvvaurp0',
#  'thanks papitasfritas helping make cool custom pin art nyc sony… httpswwwinstagramcompbed3inagwao',
#  'ok let try againhopefully without losing week lol iphone pictwittercom2blqrjukan',
#  'genius 2014 shoutouts indian malayali fun tbt tb tagging photography iphone… httpinstagramcompw4auz1vagv',
#  'best start day sausage sausagesandwich yum tasty apple porkandapple… httpswwwinstagramcompbbzfqb7jcqz',
#  'fisherprice laugh learn learning apple baby toy httpbitly2mapibq fisherpricepictwittercompp5aeihvv8',
#  'day actually wanted take photo day trip pissedoff',
#  'third time today ive charge phone iphone',
#  'want download free iphone app today spread style itwantithaveit fblogger httpowlya1ifc',
#  'pic said would appreciated muzzle flash cavitation bullet got ta iphone slomo cool funny perfectpictwittercomhh2nzggylb',
#  'good birthday purchase happy applewatch spacegray applewatchsport sport apple httpsinstagramcomp3ppylpakb',
#  'birthday ronnie birthday money vodka balloon lynx wirelesscharger samsung spoilt httpswwwinstagramcompbjl2isrg6gc',
#  'taking extra credit survey phone literally giving apple worst review ever oo whydoihaveaniphone',
#  'next race tour du maroc fonzi ehi sbronzidifonzi limitless goodvibes cyclist cyclistlife ride365 nevergiveup instagood instagramer photooftheday season2018 iphonex picoftheday smile instalike igers man cool lifestyle casablancapictwittercomqo0wmco76j',
#  'would like wish amazing day make every minute count tl today iphone accessory news life april 16 2015 070…',
#  'hello samsung galaxys8 borderless phone new nice … httpswwwinstagramcompbtg2rfrhclvcjx1pklwnra3yvqslfor5xni0 …',
#  'apple mail program starting could beginning end apple',
#  '118mb apple update currently 64th minute seems detroyed pc',
#  'far im loving magic mouse mouse apple mac httpbitly3iamzd',
#  'hello lovely newphone iphone iphone6s apple yay gold 64gb httpsinstagramcomp8qof9fielz',
#  'raffle winner samsung galaxy ticket 0051 beaboutique star blue newyear 20 httpinstagrampt9iq7sk7uz',
#  'campaign samsung samsung campaign work photo job model smile nildosalvatori… httpswwwinstagramcompbvaclxtaudl',
#  'fat roll cellulite kim… httpdlvritlcgzlx news photography fashion health fail tech ipad iphone funny lol',
#  'colorsplash iphone found heart virtually sliding hand art ego designermonday httptwitpiccom7i5oh',
#  'late post iphone finally came yesterday went plus iphone gcu blessed… httpinstagramcompuliu0fmhlo',
#  'unlock level zen block coming soon relax iphone summer sun mobilegame chill music android weekend veganpictwittercom3aftayddv0',
#  'follow capetownsup instagram httpmfttedvfh sup surf fun capetown funny sexy samsung pictwittercomso7w6poy5n',
#  'u find \ue32c instagram iphoneography iphonesia iphone webstagram instago coffee starbucks irini httpinstagramplxgk3',
#  'black friday success black friday smartv samsung 46in thanksgiving true… httpinstagramcomphsek8kmxm5',
#  'jdholic well seeing iphone clearly le 7 acceptable',
#  'prophet husband iphone httpifttt2bor0kb android httpifttt2asurcj kindle book march 17 2017 0…',
#  'got 10 sub goal unbelievable thank everyone support httpwwwtwitchtvjdkong905 twitch twitchtv twitchstreamer twitchaffiliate prime subscribe follow hype ps4 gaming blessed game sony thankyou smallsteps',
#  'ıcecream cream chocolate apple banana pineapple strawberry fruitsalad httpinstagramcompygc8nphxnp',
#  'stuff dream made nerd iphone clothes iphone fashion juicycouture christianlouboutin httpinstagrampi19fc',
#  'apple iphone inear headphone actually fit ear human designingforaliens',
#  'birthday girl samsung tv presets thanksmom grateful surprise httpinstagrampsyoi42lxpb',
#  'thanks apple telling restore iphone forgot tell take 4 hour',
#  'live picoftheday iphone beard ink tattoo yolo rock work on… httpswwwinstagramcompbnnn7auhrbg',
#  'oppomobileindia guyz dont provide colour o update android update novalueformoney',
#  '2016 year apple come apple watch left handed people apple watch applewatch new year',
#  'map app get u completely lost guy deserved fired need app actually work iphone',
#  'apple fucking stupid something simple task cant even fuck apple macbookpro apple needsmoarpc',
#  'home button randomly get stuck gently press open screen iphone',
#  'watch tyga squirm away ross… httpdlvritlyr6ht news photography fashion health fail tech ipad iphone funny lol',
#  'wifi haking password httpsgooglzhz9lr android apps unitedstate cute color igers iphoneonly guitarplayer iphone',
#  'preordered payed full playstation 4 playstation ps4 nextgen sony',
#  'people annoying new iphone phone phone thing apple important',
#  'new display picture iphoneography iphone instagram iphonesia photography photooftheday beautiful httpinstagrampq0qgr',
#  'would like wish amazing day make every minute count tl today iphone accessory news life may 06 2016 0700am',
#  'apple charger worst ive bought 10 ten iphone charger year two melted worst',
#  'rt larryhwan selfie indonesia shopping fun cute style samsung tablet tab3 design fashion httpgooglwe5kzd',
#  'samsung gear vr shae transported world healthy fitpictwittercomeh4cxe0eqp',
#  '3 new note 3 happy left apple breakup peaceout customer myphonesmybaby samsung',
#  'finally got new phone couldntlivewithoutit samsung galaxys3 samsung blue stallingborough httpinstagrampwwhflgdhhc',
#  'iphone suck keep screwing shut freeze jazz',
#  'new present apple mini cute katespade tablet toronto ipad yokdale spoiled white… httpinstagramcompz5fedmv1gw',
#  'true realtalk girltalk heartbreak true truth quote picoftheday iphone instagirl tattooedgi httpinstagrampnvu6torqne',
#  'greatness choice streetfighter mortalkombat gameofthrones batman superman superpower superhero wwe dragonballz pokemon fighting onlineshopping tshirt tshirts apparel beauty art quote meaningfulquotes sexy girl boy kid child iphone pictwittercomynv68yew8b',
#  'got simply love iphone6splus iphone newiphone apple pictwittercomos18hxuam7',
#  'apple shop visit needed volume button going break',
#  'fuck homework homework suck apple mac pro book wtc twintowers 911 pp httpinstagramprflw1chelt',
#  'happy cute apple family loyal apple macbook macbookpro ipad iphone6 halloween… httpsinstagramcomp80s4bdnbrz',
#  'winner new apple ipod itouch cranemachine beacharcade north rehobothbeach delaware httpfbme5dhoatruy',
#  'iphone app elimi flirting game play meet date new people social network httptinyurlcommqsg6f5',
#  'heyemmadonnell man 200quid cause flash cant get apps ipod since theyve updated app software 3',
#  'received new iphone x thank u httpbitly2glspiw iphone apple io appleiphone iphonex phone',
#  'deal thank nang ting hahahaha love yah gift cousin phone samsung vsco… httpinstagramcomppaodzgfobf',
#  'yay finally fixed apple issue genius couldnt help rockingtherazernowpictwittercomjt2vn4xbpb',
#  'eeeekkkkk happy came today newtoy electronic dream samsung tablet baby home… httpinstagramcompevfv6il9rd',
#  'weve got high tech apple computer cl yet computer many issue restart everyday day',
#  'would like wish amazing day make every minute count tl today iphone accessory news life february 02 2017 0…',
#  'wow fuck apple put new p code ipad lock go put wont unlock disabled ipad',
#  'blackeysbeats mine didnt even decency split concertinad died pictwittercomw2wz5s0k7z',
#  'laptop get nerve seriously want mac fuckpc fuck pcisgay apple httpinstagramcompakb3t5trc',
#  'restored iphone deleted music apps still wont sync apple',
#  'announce urban christmas stickies appstore imessage urbanplace sticker apple httpsitunesapplecomappapplestoreid1178546215pt502389cttwittermt8 …',
#  'invested 4k player match tv co amazon prime deal disc arriving tomorrow tonight im visual feast 4k sony uhd bluray bladerunner2049 bladerunner revenant lifeofpi interstellar themartian tv excited amazondeal amazonprimeday amazonpictwittercomwt8hbgurpw',
#  'finally got cable 2 meter longd iamhappy samsung usbcable excited pretty… httpinstagramcompblh1vur2q',
#  'need jaffacakes food drink smirnoff green apple vodka bunny night… httpinstagramcompyntjqqk4u3',
#  'reallyreal app approved iphone ipad dating college httpreallyrealcom college singlepictwittercom0d9dzq0cxo',
#  'birthday present laura arrived birthday apple appletv 1080p applegeek… httpinstagramcompxmjstvhu0z',
#  'trying download ios8 dad fone 1 ghante se download ho rha',
#  'rt followbacg follow4followi justinbieber apple ipad iphone april 22 2011 0701amapril 22 2011 0701am',
#  'feel love receive 5 iphone screen repair entire month february iphone valentinesday crackedscreenpictwittercomat3utotabe',
#  'hugeplumbs someone said something similar update via itunes though',
#  'craving vsco instalike vscocam vscoph vscofilter iphone me… httpswwwinstagramcompbrxru8eg8wo',
#  'fucking iphone autocorrect belichick belichek time',
#  'summer back summer tshirt iphone gay blue hot selfie mirror wednesday david house httpinstagramcompl7c8geiw',
#  'good night friend smile laugh work adobe apple illustrator photoshop samsung underarmour hondalife gopro s7edgepictwittercomobuiheud4m',
#  'love coworkers give fruit snack apple fruitsnack httpswwwinstagramcompbjjhorrbux',
#  'im wondering samsungblast jean pocket thank god im samsung user httpstwittercomzaferminhajstatus795238754608971777 …',
#  'trial apple iphone getting one im going get samsung smartphone bad screen',
#  'man infinity myman potd live instagood instalove samsung black… httpinstagramcompbjkkxy0pg',
#  'say perfect day perfect sunset like iphone mexico httpinstagramcompljstptrh8',
#  'seriously dont care iphone track everywhere show much stevejobs care yea apple much',
#  'apple lieee fake apple michael hungry fatlife httpinstagrampwyj3pfmd',
#  'apple iphone 5 leather case smart apple iphone style swag cool rawagroup… httpswwwinstagramcompbjnovxbberl',
#  'wip hpcase samsung note flower cute fun madeforyou handmade craft instacraft by… httpinstagramcompg8holiapti',
#  'photo arguing new game psp sony game hobby cousin kid httptmblrcoznhbmyz1smu1',
#  'samsungmobile yousuck worst mobile worst service worst executive never suggest anyone samsung mobile',
#  'xcode installation failed im told contact software manufacturer assistance apple',
#  'finally baby heresamsung galaxy s4 photooftheday instaphoto world wide followback httpinstagramcompiw2zxk6n6',
#  'factory reset iphone instantly tell storage full bull there nothing apple nostoragemyass',
#  'beauty shopping aliusaexpress iphone io app cat s40 16gb unlocked gsm 4g lte refinedrugged ip68 httpowlyyqmv505nz6b',
#  'welcome family future samsung s9 consultancy ilovemyjob bethefirst… httpswwwinstagramcompbgyyfpfdfpk',
#  'feeling like buying galaxy tab raise middle finger sky apple',
#  'yo ill longer team iphone use upgrade goodbyeiphone apple',
#  'hey dur cute pretty adorable beautiful girl style makeup awesome moustache iphone… httpinstagramcompessbyha12q',
#  'finally new phone galaxy samsung muchneeded excited s5 thenextbigthing … httpinstagramcomptyxtlbkx4',
#  'bought ps3 year ago last guardian getting cancelled one pissed person sony',
#  'apple ios7 absolute hybrid windows8 android yet apple fan say apple innovates microsoft',
#  'bringing focus mm 104x50x60 2018 metroman moscow bringing focus near conclusion metroman moscow weekend iphone photography 7 artistsontwitter life weekend iphone photography 7 artistsontwitter life pictwittercomirjoqni9js',
#  'amandagrybowski ashole cant believe u took convo brandnew iphone',
#  'dear apple im u making download huge update slows phone u come wa new one get',
#  'conniebritton charlesesten dont know face tweet iphone',
#  'hateapple new updated itunes 11 far le functionality predecessor well done idiot utter rubbish',
#  'happiness new gadget gift fromm brotherinlaw samsung tab3 flying instaddict… httpinstagramcompnydw73jtga',
#  'hk case came today hellokitty hk asian phone case iphone obsessed blue white bow httpinstagramposys4i2zg',
#  'shiniest reddest apple weekend officially peaked weekend apple fridayfeeling',
#  'ui io design app iphone beauty day 002 beauty profile app wavegraphic dribbblehttpsdribbblecomshots2326768day002beautyprofileapp …',
#  'samsung galaxy tab 2 70 lovely mom samsung galaxy tablet gift lymom instagram httpinstagrampwgosnqprcj',
#  'designermonday art colorsplash httpbitly3hkao brush httpbitly2ozg5 typedrawing httpbitlyxowab iphone',
#  'iphone restored latest backup month ago textcalled yesterday dont know ab',
#  'razihel bad boy matzo tiesto edm r3hab rebound life cool ps4 sony xboxone… httpinstagramcompmyodghj7sz',
#  'amount hate apple itunes intense',
#  'great siri io 6 work iphone4s thenewipad whats wrong iphone4 apple',
#  'charge iphone comfort mobile power go iphone7 iphone7powerbankcase iphone apple accessory gadget phone paccenter abuja abujafct abujapeople wuse abujaphones gadget abujacity capitalhub buy sale fct service tech retweetpictwittercomfiajxhnzqg',
#  'suckerrrrr self selfie suck lollypop candy sweet green apple caramel yum tasty girl… httpinstagramcompbh25nfohsd',
#  'new phonecase phonecase case tribal pattern white phone samsung cute beautiful… httpinstagramcompcrlfukxdju',
#  'thank grandpa grandpa gift cellphone sony xperia z like likeplease … httpinstagramcompxmshjkju3',
#  'bought apple wireless keyboard stunned size tiny comparison old logitechs530 keyboard',
#  'valentine love love360 httpsitunesapplecomusapplove360id809353957mt8 … idol rt daughter quote valentineapp iphone 爱 757',
#  'filter needed lavender iphonex portraitmode fave holiday summer dorset floral scent sunshine grow instagram instagood insta instaflower kingston lacy httpswwwinstagramcompbldl9xmnrxoutmsourceigtwittershareigshid1w7asrcnt2z8t …',
#  'iphone doesnt want charge 3rd party charger conspiracy wacksauce',
#  'valentinesday everyone sday round stone cool frozen snow heart reflection winter sony httpgooglf2d8y9',
#  'came mail free iphone case vickys secret pink httpinstagramporuu3irm6k',
#  'back city life goodnight music art apple iphoneonly calvinklein hair jesus… httpsinstagramcomp3pfkqglnod',
#  'follow capetownsup instagram httpmfttsbzyp sup surf fun capetown funny sexy samsung pictwittercomecm5kmfj4a',
#  'cant drag voice memo itunes pc apple usual trick trying lockin shortsighted',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow urf',
#  'sony sony white mdr pair headphone music b treble beat httpinstagramcomplriil5xysr',
#  'moby buy cool gift today sony iphone samsung tablet httpbuffly1pe50vy',
#  'learn math sum ibbleobble httpbitly2enyssf educational math game kid child kindergarten school school preschool homeschool homeschooling ipad iphone appletv indiedev playschool learning learnmaths number fridayfeelingpictwittercom3ysfvny6uf',
#  'looking awesome awesome woodworking greatful yoga iphone money applewatch apple nike solareclipse ridgid ryobi trumppictwittercomd51maevtkl',
#  'new toy ipad apple 3rdgeneration shopping gift present treatyourself dandelion toy joy q httpinstagrampq8pkfqy3lj',
#  'slowhand77 drbananas 1 widget see twitter stock weather etc glance 2 huge screen get 3 plus',
#  'idk download dead nation infamous never play either one download anything sony psn playstation',
#  'ive gone thru four iphone charger 3 day bos badass',
#  ...]

# %% [markdown]
# # bag of words

# %%
#converting the text into numbers, vectors
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range=(1,2))
data_x = cv.fit_transform(corpus)
x = data_x
y = df.label

# %% [markdown]
# #classification into train and test

# %%
#classification of data into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
#creating the classifier model
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#cheking the accuracy of the created model
from sklearn import metrics
y_pred = clf.predict(x_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.842929292929293
